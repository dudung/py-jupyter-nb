# %% [markdown]
# # ipynb_hello_import
# Display 'Hello, World!' message using `ipynb_hello_module` module.

# %%
import ipynb.fs.full.hellomodule as hm

# %%
hm.greeting()
# Out:
# Hello, you!

# %%
hm.greeting("Jupyter")
# Out:
# Hello, Jupyter
