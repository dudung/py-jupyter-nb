# %% [markdown]
# # ann
# Draw artificial neural network architecture using [Mermaid](https://mermaid-js.github.io/mermaid/#/flowchart) in a Markdown file at [Github](https://github.com)

# %% [markdown]
# ## concept
# Berikut adalah konsep jaringan saraf tiruan dan contoh arsitekturnya

# %% [markdown]
# Konsep dari jaringan saraf tiruan, seperti namanya, adalah tiruan dari jaringan saraf yang dimiliki otak yang disimulasikan oleh komputer untuk melakukan sebuah tugas seperti mencari pola. Jaringan saraf tiruan terdiri dari jaringan neuron yang terdiri dari lapisan input, satu atau lebih lapisan tersembunyi dan lapisan keluaran.

# %% [markdown]
# ## architecture
# Suatu contoh arsitektur jaringan saraf tiruan (artificial neural network architecture)

# %% [markdown]
# Kode diagram alirnya dalam Mermaid adalah sebagai berikut
#
# ```mermaid
#  flowchart LR;
#     subgraph Lapisan_input;
#     I1;
#     I2;
#     I3;
#     I4;
#     end;
#     subgraph Lapisan_hidden_layer_1;
#     HL1_1;
#     HL1_2;
#     HL1_3;
#     HL1_4;
#     end;
#     subgraph Lapisan_hidden_layer_2;
#     HL2_1;
#     HL2_2;
#     HL2_3;
#     HL2_4;
#     end;
#     subgraph Lapisan_output;
#     O1;
#     O2;
#     O3;
#     end;
#
#     I1 ---> HL1_1;
#     I1 ---> HL1_2;
#     I1 ---> HL1_3;
#     I1 ---> HL1_4;
#     I2 ---> HL1_1;
#     I2 ---> HL1_2;
#     I2 ---> HL1_3;
#     I2 ---> HL1_4;
#     I3 ---> HL1_1;
#     I3 ---> HL1_2;
#     I3 ---> HL1_3;
#     I3 ---> HL1_4;
#     I4 ---> HL1_1;
#     I4 ---> HL1_2;
#     I4 ---> HL1_3;
#     I4 ---> HL1_4;
#     HL1_1 ---> HL2_1;
#     HL1_1 ---> HL2_2;
#     HL1_1 ---> HL2_3;
#     HL1_1 ---> HL2_4;
#     HL1_2 ---> HL2_1;
#     HL1_2 ---> HL2_2;
#     HL1_2 ---> HL2_3;
#     HL1_2 ---> HL2_4;
#     HL1_3 ---> HL2_1;
#     HL1_3 ---> HL2_2;
#     HL1_3 ---> HL2_3;
#     HL1_3 ---> HL2_4;
#     HL1_4 ---> HL2_1;
#     HL1_4 ---> HL2_2;
#     HL1_4 ---> HL2_3;
#     HL1_4 ---> HL2_4;
#     HL2_1 ---> O1;
#     HL2_1 ---> O2;
#     HL2_1 ---> O3;
#     HL2_2 ---> O1;
#     HL2_2 ---> O2;
#     HL2_2 ---> O3;
#     HL2_3 ---> O1;
#     HL2_3 ---> O2;
#     HL2_3 ---> O3;
#     HL2_4 ---> O1;
#     HL2_4 ---> O2;
#     HL2_4 ---> O3;
# ```
#
# yang hasilnya dapat dilihat dalam berkas [ann.md](ann.md).

# %%
# %load_ext nb_js_diagrammers

# %%
# %%mermaid_magic
#
# flowchart LR;
#     subgraph Lapisan_input;
#     I1;
#     I2;
#     I3;
#     I4;
#     end;
#     subgraph Lapisan_hidden_layer_1;
#     HL1_1;
#     HL1_2;
#     HL1_3;
#     HL1_4;
#     end;
#     subgraph Lapisan_hidden_layer_2;
#     HL2_1;
#     HL2_2;
#     HL2_3;
#     HL2_4;
#     end;
#     subgraph Lapisan_output;
#     O1;
#     O2;
#     O3;
#     end;
#
#     I1 ---> HL1_1;
#     I1 ---> HL1_2;
#     I1 ---> HL1_3;
#     I1 ---> HL1_4;
#     I2 ---> HL1_1;
#     I2 ---> HL1_2;
#     I2 ---> HL1_3;
#     I2 ---> HL1_4;
#     I3 ---> HL1_1;
#     I3 ---> HL1_2;
#     I3 ---> HL1_3;
#     I3 ---> HL1_4;
#     I4 ---> HL1_1;
#     I4 ---> HL1_2;
#     I4 ---> HL1_3;
#     I4 ---> HL1_4;
#     HL1_1 ---> HL2_1;
#     HL1_1 ---> HL2_2;
#     HL1_1 ---> HL2_3;
#     HL1_1 ---> HL2_4;
#     HL1_2 ---> HL2_1;
#     HL1_2 ---> HL2_2;
#     HL1_2 ---> HL2_3;
#     HL1_2 ---> HL2_4;
#     HL1_3 ---> HL2_1;
#     HL1_3 ---> HL2_2;
#     HL1_3 ---> HL2_3;
#     HL1_3 ---> HL2_4;
#     HL1_4 ---> HL2_1;
#     HL1_4 ---> HL2_2;
#     HL1_4 ---> HL2_3;
#     HL1_4 ---> HL2_4;
#     HL2_1 ---> O1;
#     HL2_1 ---> O2;
#     HL2_1 ---> O3;
#     HL2_2 ---> O1;
#     HL2_2 ---> O2;
#     HL2_2 ---> O3;
#     HL2_3 ---> O1;
#     HL2_3 ---> O2;
#     HL2_3 ---> O3;
#     HL2_4 ---> O1;
#     HL2_4 ---> O2;
#     HL2_4 ---> O3;
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;body&gt;
#         &lt;script src=&quot;https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#             mermaid.initialize({ startOnLoad: true });
#         &lt;/script&gt;
#
#         &lt;div class=&quot;mermaid&quot;&gt;
#
# flowchart LR;
#     subgraph Lapisan_input;
#     I1;
#     I2;
#     I3;
#     I4;
#     end;
#     subgraph Lapisan_hidden_layer_1;
#     HL1_1;
#     HL1_2;
#     HL1_3;
#     HL1_4;
#     end;
#     subgraph Lapisan_hidden_layer_2;
#     HL2_1;
#     HL2_2;
#     HL2_3;
#     HL2_4;
#     end;
#     subgraph Lapisan_output;
#     O1;
#     O2;
#     O3;
#     end;
#
#     I1 ---&gt; HL1_1;
#     I1 ---&gt; HL1_2;
#     I1 ---&gt; HL1_3;
#     I1 ---&gt; HL1_4;
#     I2 ---&gt; HL1_1;
#     I2 ---&gt; HL1_2;
#     I2 ---&gt; HL1_3;
#     I2 ---&gt; HL1_4;
#     I3 ---&gt; HL1_1;
#     I3 ---&gt; HL1_2;
#     I3 ---&gt; HL1_3;
#     I3 ---&gt; HL1_4;
# ...

# %% [markdown]
# ## references

# %% [markdown]
# ```
# 1. IBM Cloud Education, "Neural Networks", 17 August 2020, url : https://www.ibm.com/cloud/learn/neural-networks
# 2. Abbod, Maysam F (2007). "Application of Artificial Intelligence to the Management of Urological Cancer". The Journal of Urology. 178 (4): 1150–1156.
# 3. https://mermaid-js.github.io/mermaid/#/flowchart
# ```
