# %% [markdown]
# # hello_test
# test of hello module

# %%
import sys
from pathlib import Path

src_path = Path.cwd().parents[0].parents[0]
module_path = str(src_path / "inhouse\modules")
if module_path not in sys.path:
    sys.path.insert(0, module_path)
    pass

from ipynb.fs.full.unnamed import hello as greet

# %%
# use it without argment
print(greet())
# Out:
# Hello, World!

# %%
# use it with argument
print(greet("Einstein"))
# Out:
# Hello, Einstein!

# %%
# get help of it
help(greet)
# Out:
# Help on function hello in module ipynb.fs.full.unnamed:
#
# hello(name='World')
#     Greet person with name
#
#     Args:
#         name: person name
#
#     Returns:
#         Greeting to person with name
