# %% [markdown]
# # bee_pollination_model

# %%
# EMT (effective medium theory) model
import matplotlib.pyplot as plt
import numpy as np

tmin = 0
tmax = 240
Nt = 240
t = np.linspace(tmin, tmax, Nt)
f1 = t


fig = plt.figure()
fig.set_figwidth(20)
fig.set_figheight(2)

plt.xticks(np.arange(min(t), max(t)+1, 24))
plt.yticks(np.arange(min(f1), ma, 1))
plt.plot(t, f1)

plt.legend(["f1 = linear"])

plt.xlabel("t (hour)")
plt.ylabel("linear")

plt.show()
