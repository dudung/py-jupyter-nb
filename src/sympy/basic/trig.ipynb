# %% [markdown]
# # trig
# Some trigonometric functions using numeric and sympy library

# %% [markdown]
# ## numerical power

# %%
x = 5
y = 3
z = x ** y

print(f"x**y = {x} * {y} = {z}")
# Out:
# x**y = 5 * 3 = 125

# %% [markdown]
# ## symbolic power

# %% [markdown]
# $$
# z = x^y
# $$

# %%
from sympy import symbols

x, y = symbols('x y')
z = x ** y
print('z = ', z)
# Out:
# z =  x**y
