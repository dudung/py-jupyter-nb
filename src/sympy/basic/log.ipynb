# %% [markdown]
# # log
# Natural logarithm of a number using math module and sympy library

# %%
import math
x = 0
y = math.exp(x)
print(x, y)

x = 1
y = math.exp(x)
print(x, y)
# Out:
# 0 1.0
# 1 2.718281828459045

# %%
import sympy
x = sympy.symbols('x')
y = sympy.exp(x)
print(x, y)
# Out:
# x exp(x)
