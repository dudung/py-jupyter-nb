# %% [markdown]
# # steffensen_method
# Find a root in an interval using steffensen's method

# %% [markdown]
# $$\tag{1}
# f(x) = \sin(x - 0.26\pi) - 0.41
# $$

# %%
import math

def f(x):
    y = math.sin(x - 0.26 * math.pi) - 0.41
    return y

x = [i * 0.03  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

# %% [markdown]
# $$\tag{2}
# x_{n+1} = x_n - \frac{f^2(x_n)}{f(x_n + f(x_n))-f(x_n)}
# $$

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)
xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
    
    x1 = x0 - ( f(x0) * f(x0) ) / ( f(x0 + f(x0)) - f(x0) )
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -2.278369E-01
# 0001 1.228879E+00 -9.497477E-03
# 0002 1.239223E+00 -4.112439E-05
# 0003 1.239268E+00 -7.967594E-10

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 1.2392681512465442
# f(root) = -7.967593806945672e-10

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
