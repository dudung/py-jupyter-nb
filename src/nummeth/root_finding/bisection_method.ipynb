# %% [markdown]
# # bisection_method
# Find a root in an interval using bisection method

# %%
import math

def f(x):
    y = math.sin(x - 0.26 * math.pi) - 0.41
    return y

x = [i * 0.03  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

xroot = [1, 2]
yroot = [f(i) for i in xroot]

print("Root existance between", xroot[0], "and", xroot[1], ":", end=' ')
if yroot[0] * yroot[1] < 0:
    print(True)
else:
    print(False)
# Out:
# Root existance between 1 and 2 : True

# %%
x1 = xroot[0]
x2 = xroot[1]
x3 = 0.5 * (x1 + x2)
xroot.append(x3)

eps = 1E-6
dx = 10
i = 2
print("iter root         f(root)")
while dx > eps and i < 100:
    x1 = xroot[i-2]
    x2 = xroot[i-1]
    x3 = xroot[i]
    
    if i == 2:
        print(f"{i-2:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
        print(f"{i-1:04d}", f"{x2:.6E}", f"{f(x2):+.6E}")
        print(f"{i:04d}", f"{x3:.6E}", f"{f(x3):+.6E}")
   
    f13 = f(x1) * f(x3)
    f23 = f(x2) * f(x3)
     
    if f13 < 0:
        x4 = 0.5 * (x1 + x3)
        xroot[i-2] = x2
        xroot[i-1] = x1
    else:
        x4 = 0.5 * (x2 + x3)
    
    xroot.append(x4)
    dx = abs(f(x4))
    
    print(f"{i:04d}", f"{x4:.6E}", f"{f(x4):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -2.278369E-01
# 0001 2.000000E+00 +5.158149E-01
# 0002 1.500000E+00 +2.212671E-01
# 0002 1.250000E+00 +9.764565E-03
# 0003 1.125000E+00 -1.066695E-01
# 0004 1.187500E+00 -4.774516E-02
# 0005 1.218750E+00 -1.879930E-02
# 0006 1.234375E+00 -4.467864E-03
# 0007 1.242188E+00 +2.660944E-03
# 0008 1.238281E+00 -9.003387E-04
# 0009 1.240234E+00 +8.810864E-04
# 0010 1.239258E+00 -9.430640E-06
# 0011 1.239746E+00 +4.358768E-04
# 0012 1.239502E+00 +2.132353E-04
# 0013 1.239380E+00 +1.019054E-04
# 0014 1.239319E+00 +4.623814E-05
# 0015 1.239288E+00 +1.840394E-05
# 0016 1.239273E+00 +4.486698E-06
# 0017 1.239265E+00 -2.471959E-06
# 0018 1.239269E+00 +1.007372E-06
# 0019 1.239267E+00 -7.322926E-07

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 1.239267349243164
# f(root) = -7.322925634212218e-07

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
