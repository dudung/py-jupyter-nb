# %% [markdown]
# # newton_raphson_method
# Find a root in an interval using newton-raphson method

# %%
import math

def f(x):
    y = math.sin(x - 0.26 * math.pi) - 0.41
    return y

x = [i * 0.03  for i in range(0, 100 + 1)]
y = [f(i) for i in x]

def df(x):
    dy = math.cos(x - 0.26 * math.pi)
    return dy

# %%
xroot = []
yroot = []

x0 = 1
y0 = f(x0)

xroot.append(x0)
yroot.append(y0)

i = 1
eps = 1E-6
dx = 10
print("iter root         f(root)")
while dx > eps and i < 20:
    x0 = xroot[i-1]
    if i == 1:
        print(f"{i-1:04d}", f"{x0:.6E}", f"{f(x0):+.6E}")
    
    x1 = x0 - f(x0) / df(x0)
    
    xroot.append(x1)
    dx = abs(f(x1))
    
    print(f"{i:04d}", f"{x1:.6E}", f"{f(x1):+.6E}")
    i += 1
# Out:
# iter root         f(root)
# 0000 1.000000E+00 -2.278369E-01
# 0001 1.231714E+00 -6.901791E-03
# 0002 1.239256E+00 -1.152877E-05
# 0003 1.239268E+00 -3.275180E-11

# %%
print("root =", xroot[-1])
print("f(root) =", f(xroot[-1]))
# Out:
# root = 1.2392681520841933
# f(root) = -3.275180127104704e-11

# %%
yroot = [f(i) for i in xroot]

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x, y, '-', xroot, yroot, 'r.', lw=2)
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("f(x)")
plt.plot(yroot, 'r.-')
plt.show()

# %%
plt.grid()
plt.xlabel("iter")
plt.ylabel("x")
plt.plot(xroot, 'r.-')
plt.show()
