# %% [markdown]
# # euler_algorithm
# Very short introduction to Euler algorithm.

# %% [markdown]
# $$
# y_{n + 1} = y_n + h f(t_n, y_n)
# $$
#
# $$
# y' = f(t, y(t))
# $$
#
# $$
# t_n = t_0 + n \Delta t
# $$
#
# $$
# y_n = y(t_n)
# $$
