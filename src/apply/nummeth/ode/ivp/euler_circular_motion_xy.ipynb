# %% [markdown]
# # euler_circular_motion_xy
# Circular motion in xy coordinate with Euler algorithm.

# %% [markdown]
# $$
# y_{n + 1} = y_n + h f(t_n, y_n),
# $$
#
# $$
# y' = f(t, y(t)),
# $$
#
# $$
# y_n = y(t_n),
# $$
#
# $$
# t_n = t_0 + n \Delta t, n = 0, 1, \dots, m,
# $$
#
# $$
# h \equiv \Delta t = \frac{t_m - t_0}{m}.
# $$
