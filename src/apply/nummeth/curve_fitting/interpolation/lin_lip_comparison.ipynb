# %% [markdown]
# # lin_lip_comparison
# Test Lagrange interpolating polynomial and linear interpolation implementations with different data

# %%
# import libraries
import ipynb.fs.full.linearint as lin
import ipynb.fs.full.lagipoly as lip
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### data 1

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [0, 1, 2, 3, 4, 5]

x2 = np.linspace(0, 5, 100).tolist()
y2 = lin.linear_interpolation(x2, x1, y1)
x3 = x2.copy()
y3 = lip.lagrange_polynomial(x3, x1, y1)

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1, y1, 'ro', x2, y2, 'b--', x3, y3, 'g-')
plt.show()

# %% [markdown]
# ### data 2

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [0, 4, 6, 6, 4, 0]

x2 = np.linspace(0, 5, 100).tolist()
y2 = lin.linear_interpolation(x2, x1, y1)
x3 = x2.copy()
y3 = lip.lagrange_polynomial(x3, x1, y1)

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1, y1, 'ro', x2, y2, 'b--', x3, y3, 'g-')
plt.show()

# %% [markdown]
# ### data 3

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [-15, 10, 5, -5, -10, 15]

x2 = np.linspace(0, 5, 100).tolist()
y2 = lin.linear_interpolation(x2, x1, y1)
x3 = x2.copy()
y3 = lip.lagrange_polynomial(x3, x1, y1)

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1, y1, 'ro', x2, y2, 'b--', x3, y3, 'g-')
plt.show()

# %% [markdown]
# ### data 4

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [10, 0, 4, 4, 0, 10]

x2 = np.linspace(0, 5, 100).tolist()
y2 = lin.linear_interpolation(x2, x1, y1)
x3 = x2.copy()
y3 = lip.lagrange_polynomial(x3, x1, y1)

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1, y1, 'ro', x2, y2, 'b--', x3, y3, 'g-')
plt.show()

# %% [markdown]
# ### data 5

# %%
x1 = [0, 1, 2, 3, 4, 5]
y1 = [8, -2, 6, -6, 2, -8]

x2 = np.linspace(0, 5, 100).tolist()
y2 = lin.linear_interpolation(x2, x1, y1)
x3 = x2.copy()
y3 = lip.lagrange_polynomial(x3, x1, y1)

plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1, y1, 'ro', x2, y2, 'b--', x3, y3, 'g-')
plt.show()
