# %%
from lesslines.data.parametric import linear as lin
import matplotlib.pyplot as plt

param_lin = lin.Linear([0, 0], [1, 1])
x, y = param_lin.get_xy(1, 0.1, num_points=40)

plt.plot(x, y, '.--')
plt.show()
