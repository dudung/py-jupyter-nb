# %%
from lesslines.data.generated import parametric as prm
import matplotlib.pyplot as plt

# %%
x, y1 = prm.polynomial([0, 1])

plt.plot(x, y1, 'o--')
plt.show()

# %%
x, y2 = prm.polynomial([0.25, 1, -1])

plt.plot(x, y2, 'o--')
plt.show()

# %%
x, y3 = prm.polynomial([1, 1, 1])

plt.plot(x, y3, 'o--')
plt.show()

# %%
plt.plot(y2, y3, 'o--')
plt.show()
