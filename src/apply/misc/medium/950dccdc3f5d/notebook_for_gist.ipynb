# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)

X, Y = np.meshgrid(x, y)
Z = np.sqrt(X**2 + Y**2)

plt.figure(figsize=(4.8, 4.8))
plt.contourf(X, Y, Z)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
