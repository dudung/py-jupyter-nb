# %% [markdown]
# ![image.png](attachment:fbf2448d-ef91-45b8-bbcf-2779b090d14e.png)

# %%
def f(x):
    y = x**2
    return y

# %%
a = -3; b = 3; n = 7
dx = (b - a) / n

yL = 0
for i in range(n):
    xi = a + dx * i
    yL += f(xi) * dx
print('yL =', yL)
# Out:
# yL = 18.734693877551017

# %%
a = -3; b = 3; n = 7
dx = (b - a) / n

yR = 0
for i in range(n):
    xi = a + dx * i
    xj = xi + dx
    yR += f(xj) * dx
print('yR =', yR)
# Out:
# yR = 18.734693877551017

# %%
a = -3; b = 3; n = 7
dx = (b - a) / n

yM = 0
for i in range(n):
    xi = a + dx * i
    xj = xi + dx
    yM += f(0.5*(xi + xj)) * dx
print('yM =', yM)
# Out:
# yM = 17.632653061224488

# %%
a = -3; b = 3; n = 7
dx = (b - a) / n

yT = 0
for i in range(n):
    xi = a + dx * i
    xj = xi + dx
    yT += 0.5 * (f(xi) + f(xj)) * dx
print('yT =', yT)
# Out:
# yT = 18.734693877551017

# %%
a = -3; b = 3; n = 8
dx = (b - a) / n

yS = 0
for i in range(n):
    xi = a + dx * i
    xj = xi + dx
    if i // 2 == i /2:
        yS += (f(xi) + 2 * f(xj)) / 3 * dx
    else:
        yS += (2 * f(xi) + f(xj)) / 3 * dx
print('yS =', yS)
# Out:
# yS = 18.0
