# %%
x = [
    10, 20, 40, 40, 40, 60, 70,
    20, 40, 40, 40, 40, 40, 60,
    10, 20, 30, 40, 50, 60, 70,
    70, 20, 30, 40, 50, 70, 20,
]
print('x =', x)
print()
print('N =', len(x))
# Out:
# x = [10, 20, 40, 40, 40, 60, 70, 20, 40, 40, 40, 40, 40, 60, 10, 20, 30, 40, 50, 60, 70, 70, 20, 30, 40, 50, 70, 20]
#
# N = 28

# %%
y = sorted(x)
print(y)
# Out:
# [10, 10, 20, 20, 20, 20, 20, 30, 30, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 50, 50, 60, 60, 60, 70, 70, 70, 70]

# %%
med = (y[13] + y[14]) / 2
print('median =', med)
# Out:
# median = 40.0

# %%
import statistics as stat
print(stat.median(y))
# Out:
# 40.0

# %%
rng = y[-1] - y[0]
print('range =', rng)
# Out:
# range = 60

# %%
rng = x[-1] - x[0]
print('range =', rng)
# Out:
# range = 10

# %%
sx = sum(x)
N = len(x)
mean = sx / N
print('mean =', mean)
# Out:
# mean = 40.714285714285715

# %%
import statistics as stat
print(stat.mean(x))
# Out:
# 40.714285714285715

# %%
sy = sum(y)
N = len(y)
mean = sy / N
print('mean =', mean)
# Out:
# mean = 40.714285714285715

# %%
import statistics as stat
print(stat.mean(y))
# Out:
# 40.714285714285715

# %%
import statistics as stat
print(stat.mode(y))
# Out:
# 40

# %%
import statistics as stat
print('mode =', stat.mode(x))
# Out:
# mode = 40

# %%
print(x)
# Out:
# [10, 20, 40, 40, 40, 60, 70, 20, 40, 40, 40, 40, 40, 60, 10, 20, 30, 40, 50, 60, 70, 20, 20, 30, 40, 50, 70, 70]

# %%
mid = (x[13] + x[14]) / 2
print('mid value =', mid)
# Out:
# mid value = 35.0

# %%
import statistics as stat
print(stat.median(x))
# Out:
# 40.0

# %%
import matplotlib.pyplot as plt
plt.hist(x, bins=7, range=[10, 80])
plt.yticks(range(0, 11,1))
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(y, bins=7, range=[10, 80])
plt.yticks(range(0, 11,1))
plt.grid()
plt.show()

# %%
x = [ 10, 11, 12, 13, 14, 
    30, 50, 59, 70, 72, 73]
import matplotlib.pyplot as plt
plt.hist(x, bins=7, range=[10, 80])
plt.yticks(range(0, 7,1))
plt.xticks(range(10, 90, 10))
plt.grid()
plt.show()

# %%
x = [ 10, 11, 12, 13, 14, 
    30, 50, 59, 70, 72, 73]
import matplotlib.pyplot as plt
plt.hist(x, bins=4, range=[10, 80])
plt.yticks(range(0, 7, 1))
plt.xticks([10, 27, 45, 62])
plt.grid()
plt.show()

# %%
x = [ 10, 11, 12, 13, 14, 
    30, 50, 59, 70, 72, 73]
import matplotlib.pyplot as plt
plt.hist(x, bins=2, range=[10, 80])
plt.yticks(range(0, 7,1))
plt.xticks([10, 45])
plt.grid()
plt.show()

# %%
x = [ 10, 11, 12, 13, 14, 
    30, 50, 59, 70, 72, 73]
import matplotlib.pyplot as plt
plt.hist(x, bins=19, range=[10, 80])
plt.yticks(range(0, 7,1))
plt.xticks(range(10, 80, 4))
plt.grid()
plt.show()

# %%
import random as rnd
x = [
    rnd.randint(10, 80)
    for i in range(0, 100)
]
print(x)
# Out:
# [77, 69, 40, 45, 68, 49, 29, 22, 12, 31, 10, 14, 54, 69, 40, 75, 69, 47, 49, 29, 38, 39, 67, 41, 47, 67, 25, 47, 50, 42, 19, 33, 18, 55, 65, 36, 65, 79, 53, 37, 10, 62, 20, 69, 36, 32, 19, 23, 27, 63, 61, 31, 72, 36, 21, 61, 58, 61, 73, 18, 12, 11, 25, 64, 30, 43, 29, 48, 58, 35, 23, 13, 43, 35, 38, 72, 53, 71, 15, 36, 36, 74, 44, 33, 10, 40, 76, 27, 78, 43, 15, 20, 70, 27, 40, 54, 68, 16, 54, 16]

# %%
import matplotlib.pyplot as plt
plt.hist(x, bins=7, range=[10, 80])
plt.grid()
plt.show()
