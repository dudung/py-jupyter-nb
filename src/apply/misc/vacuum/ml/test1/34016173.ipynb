# %%
## Bagian 1
from matplotlib import pyplot as plt
img = plt.imread('C:/Users/BOCAH/Documents/PENTING!/UTS DATA SAINS_21181085/piramid.png')
plt.imshow(img)
plt.show()

# %%
## Bagian 2
 # Data bagaikan harta karun yang menyimpan banyak informasi. Berguna untuk:
  # - Menemukan pola dan tren: seperti mencari tahu kebiasaan berbelanja pelanggan atau melacak penyebaran virus.
  # - Membuat prediksi: seperti memprediksi penjualan produk di masa depan atau memprediksi risiko penyakit.
  # - Membuat keputusan yang lebih baik: seperti memilih strategi pemasaran yang tepat atau menentukan pengobatan yang efektif.
 # Namun, metadata (data mentah) bagaikan tumpukan berlian yang belum diasah. berguna untuk:
  # - Menemukan data yang relevan: seperti mencari dokumen tentang topik tertentu atau menemukan file yang terakhir diubah.
  # - Memahami data: seperti mengetahui siapa yang membuat data, kapan data dibuat, dan apa arti data tersebut.
  # - Mengatur data: seperti mengelompokkan data berdasarkan kategori atau menyimpan data dengan rapi.
 # Analogi:
  # kita memiliki gudang yang penuh dengan barang, metadata adalah seperti label pada setiap barang. label tersebut memberitahu kamu apa isi barang, kapan barang tersebut dibeli, dan di mana barang tersebut harus disimpan.
# Tiga Jenis Metadata:
  # Metadata deskriptif: memberitahu tentang isi data, seperti judul, penulis, dan tanggal.
  # Metadata struktural: memberitahu tentang struktur data, seperti format file dan hubungan antar data.
  # Metadata administratif: memberitahu tentang pengelolaan data, seperti hak akses dan riwayat perubahan

# %%
## nomor 3
 # Jika saya seorang data scientist, pekerjaan saya adalah pekerjaan yang focus kepada mengumpulkan, membersikan, dan menganalisis data dari berbagai sumber, seperti :
  # - Transaksi keuangan
  # - Data sensor
  # - Kuisioner
 # Tujuannya adalah untuk menemukan polda dan tren, membuat prediksi, memberikan solusi untuk berbagai masalah (bidang bisnis, Kesehatan, pemerintahan, dan lingkungan)
 # Aspek fundamental dari data science adalah :
  # 1. Matematika dan Statistik:
   # Digunakan untuk memahami data, membuat model, dan menguji hipotesis.
  # 2. Pemrograman:
   # Digunakan untuk mengumpulkan data, membangun model, dan memvisualisasikan hasil.
  # 3. Komunikasi:
   # Digunakan untuk menyampaikan hasil analisis kepada orang lain dengan cara yang mudah dipahami.
 # Contoh:
 # Sebuah perusahaan e-commerce ingin meningkatkan penjualan. 
 # Seorang ilmuwan data dapat menganalisis data pembelian pelanggan untuk menemukan pola dan membuat prediksi. 
 # Hasilnya dapat digunakan untuk merekomendasikan produk kepada pelanggan dan meningkatkan konversi.

# %%
## nomor 4
 # Reprodusibilitas berarti program dapat dijalankan dengan hasil yang sama di komputer yang berbeda. Hal ini penting untuk program yang kompleks dan menggunakan banyak library dan package versi tertentu.
 # Virtual environment di Python adalah solusi untuk memastikan reprodusibilitas. 
 # Berikut cara kerjanya:
  # - Membuat virtual environment:
   # python -m venv venv #
  # - Menginstal library dan package:
   # pip install -r requirements.txt #
  # - Menjalankan program:
   # python program.py #
 # Virtual environment:
  # - Membuat ruang terisolasi untuk program.
  # - Menginstal library dan package yang dibutuhkan program.
  # - Memisahkan library dan package program dari library dan package sistem.
 # Manfaat:
  # - Memastikan program dapat dijalankan dengan hasil yang sama di komputer yang berbeda.
  # - Mencegah konflik antara library dan package program dan library dan package sistem.
  # - Membuat program lebih mudah dibagikan dan diinstal.
 # Contoh:
 # Seorang programmer mengembangkan program yang menggunakan library TensorFlow versi 2.0.
 # Programmer ingin memastikan program dapat dijalankan di komputer lain dengan hasil yang sama.
 # Programmer menggunakan virtual environment untuk menginstal TensorFlow versi 2.0.
 # Program dapat dijalankan di komputer lain dengan hasil yang sama.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("C:/Users/BOCAH/Documents/PENTING!/UTS DATA SAINS_21181085/data06.csv")

# Grafik Bar untuk Populasi
plt.figure(figsize=(10, 5))
plt.bar(df['Province'], df['Population 2020'], color='blue', alpha=0.5, label='2020')
plt.bar(df['Province'], df['Population 2021'], color='green', alpha=0.5, label='2021')
plt.xlabel('Province')
plt.ylabel('Population')
plt.title('Population Comparison by Province (2020 vs 2021)')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Grafik Garis untuk GDP
plt.figure(figsize=(10, 5))
plt.plot(df['Province'], df['GDP 2020'], marker='o', linestyle='-', color='blue', label='2020')
plt.plot(df['Province'], df['GDP 2021'], marker='o', linestyle='-', color='green', label='2021')
plt.xlabel('Province')
plt.ylabel('GDP')
plt.title('GDP Comparison by Province (2020 vs 2021)')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
