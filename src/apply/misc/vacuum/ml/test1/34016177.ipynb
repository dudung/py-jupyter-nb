# %%
# Nomor 1
import matplotlib.pyplot as plt

img = plt.imread("D:/Users/DELL/Pictures/Screenshots/Screenshot 2024-03-21 133208.png")
plt.imshow(img)
plt.show()

# %%
# Nomor 1 ( Penjelasan )
# Jelaskan arah waktu dari masa lalu ( pengalaman ) dan masa depan ( kebaruan )
# JAWAB :
# Arah waktu dari masa lalu (pengalaman) ke masa depan (kebaruan) mencerminkan evolusi dari apa yang telah 
# kita pelajari dan alami menjadi apa yang dapat kita rancang, temukan, dan wujudkan. Masa lalu adalah 
# kumpulan pengalaman, peristiwa, dan data yang telah terjadi sebelumnya, yang memberikan dasar untuk 
# pembelajaran, pemahaman, dan pengembangan pengetahuan. Dari pengalaman ini, kita memperoleh wawasan 
# tentang bagaimana keputusan sebelumnya mempengaruhi situasi saat ini dan menggunakannya sebagai titik 
# referensi untuk membuat keputusan di masa depan. Di sisi lain, masa depan merupakan domain yang belum 
# terjadi atau belum dikenal, di mana kita menjelajahi yang baru, melakukan eksperimen, dan mengejar 
# inovasi. Kebaruan melibatkan penemuan, penemuan, dan aplikasi pengetahuan yang ada untuk mengatasi 
# tantangan baru atau memenuhi kebutuhan baru, membuka jalan baru dan menjelajahi kemungkinan yang belum 
# terwujud sebelumnya. Dengan demikian, arah waktu dari masa lalu ke masa depan adalah proses yang 
# berkelanjutan, di mana pengalaman masa lalu membentuk landasan bagi penemuan dan perubahan yang akan 
# datang.

# %%
##

# %%
# Nomor 2
# Dalam konteks nilai kemanfaatannya, metadata sering kali dianggap lebih bernilai daripada data mentah. 
# Hal ini karena metadata tidak hanya memberikan informasi tentang data itu sendiri, tetapi juga 
# memberikan konteks, struktur, dan penjelasan yang penting untuk memahami serta memanfaatkan data dengan
# efektif. Metadata memungkinkan pengguna untuk dengan cepat memahami makna dan relevansi data, karena
# mereka menyediakan informasi tentang asal usul data, cara data tersebut dihasilkan, kapan data itu 
# dibuat, dan oleh siapa data tersebut dapat digunakan. Selain itu, metadata membantu dalam meningkatkan 
# aksesibilitas data dengan memfasilitasi pencarian, filtrasi, dan temuan data yang lebih efisien. 
# Mereka juga berperan dalam memperkuat integrasi antara sistem yang berbeda, karena menyediakan informasi 
# tentang format, struktur, dan metode pertukaran data. Selain itu, metadata juga penting dalam manajemen 
# dan keamanan data, karena mereka memberikan informasi tentang hak akses, kebijakan penggunaan, dan 
# batasan yang berlaku untuk data tersebut. Tanpa metadata yang tepat, data dapat menjadi sulit 
# dimanfaatkan secara maksimal, terutama dalam lingkungan yang kompleks dan beragam seperti organisasi
# besar atau infrastruktur teknologi informasi yang rumit. Oleh karena itu, dalam banyak kasus, metadata 
# dianggap lebih bernilai karena memberikan konteks dan informasi tambahan yang diperlukan untuk mengelola,
# melindungi, dan memanfaatkan data dengan lebih efisien.

# Jenis - jenis metadata
# Metadata administratif menyediakan informasi penting yang berkaitan dengan pengelolaan suatu data. 
# Jenis metadata ini bisa mengatur privasi sebuah data sehingga tidak semua orang bisa mengaksesnya. 
# Ada pun contoh informasinya berupa sumber data, jenis file, hak cipta, dan informasi teknis lainnya.
# Metadata administratif terdiri dari dua bagian, yaitu metadata preservasi dan metadata right management.
# Metadata preservasi digunakan untuk kebutuhan pengarsipan, sedangkan metadata right management berisi 
# informasi mengenai lisensi, hak cipta, dan kekayaan intelektual sebuah data.

# Metadata Struktural, jenis metadata ini berfungsi untuk menyusun beberapa informasi atau data digital 
# sehingga menjadi satu kesatuan yang struktural dan saling terhubung satu sama lain. Metadata struktural 
# bekerja seperti daftar isi sehingga pengguna bisa menemukan beberapa bagian yang dibutuhkan hanya dalam 
# sekali klik. Contohnya sering diterapkan pada e-book. Metadata struktural dapat mengetahui setiap urutan
# antar bab atau halaman dalam e-book tersebut sehingga tidak sulit untuk dicari.

# Metadata Deskriptif, sesuai istilahnya, metadata deskriptif berguna untuk mengidentifikasi dan 
# mendeskripsikan beberapa informasi penting. Jenis metadata inilah yang digunakan untuk mencari dan 
# menyeleksi sumber data. Contoh informasinya berupa judul, pengarang, tahun terbit, kata kunci, dan 
# sebagainya.

# %%
##

# %%
# Nomor 3 
# Sebagai seorang data scientist, pekerjaan saya melibatkan pengumpulan, pemrosesan, analisis, dan 
# interpretasi data untuk menghasilkan wawasan yang berguna bagi organisasi atau proyek yang saya kerjakan.
# Tujuan dari ilmu data adalah untuk mengungkap pola, tren, dan hubungan yang tersembunyi dalam data, serta 
# menghasilkan pemahaman yang mendalam tentang fenomena yang diamati. Dengan memanfaatkan teknik-teknik 
# statistik, pemodelan matematika, dan pembelajaran mesin, saya dapat membantu dalam mengambil keputusan 
# yang lebih baik, merumuskan strategi yang lebih efektif, dan mengidentifikasi peluang baru. Aspek 
# fundamental dari data science meliputi pengumpulan data dari berbagai sumber, pemrosesan data untuk 
# memastikan kualitasnya, analisis data untuk mengidentifikasi pola dan tren, serta interpretasi hasil 
# analisis untuk pengambilan keputusan yang tepat. Dengan demikian, ilmu data adalah alat yang kuat untuk 
# memahami dunia di sekitar kita dan memanfaatkan potensi data untuk mencapai tujuan bisnis dan ilmiah. 
# Singkatnya, Data Scientist adalah jembatan antara data dan pengetahuan, memungkinkan dunia untuk 
# memanfaatkan kekuatan data dan mencapai masa depan yang lebih cerah.
# Melalui pengumpulan, pemrosesan, analisis, dan interpretasi data, saya mencari pola, tren, dan hubungan 
# yang dapat memberikan wawasan yang bermanfaat bagi organisasi atau proyek yang saya kerjakan. Ilmu data 
# membutuhkan pemahaman mendalam tentang statistik, matematika, dan pemrograman, serta kemampuan untuk
# menerapkan algoritma dan model pemodelan untuk memecahkan berbagai masalah.

# %%
##

# %%
# Nomor 4
# Reprodusibilitas suatu program kompleks yang melibatkan banyak library dan package dengan versi 
# tertentu merupakan aspek krusial dalam pengembangan perangkat lunak. Fitur virtual environment di 
# Python memberikan solusi yang sangat efektif untuk memastikan reprodusibilitas tersebut. Dengan 
# menggunakan virtual environment, kita dapat menciptakan lingkungan Python yang terisolasi dan independen, 
# yang memungkinkan kita untuk mengelola dependensi dan versi library secara terpisah dari lingkungan Python 
# global yang ada di sistem operasi.
# Keuntungan utama dari penggunaan virtual environment adalah kemampuannya untuk menyimpan daftar 
# dependensi dan versi yang spesifik untuk suatu proyek dalam sebuah lingkungan yang terisolasi. Ini berarti 
# kita dapat menentukan versi tertentu dari setiap library dan package yang dibutuhkan dalam file konfigurasi
# seperti requirements.txt atau environment.yml. Dengan melakukan ini, kita dapat memastikan bahwa proyek 
# dapat dijalankan dengan konsisten pada lingkungan pengembangan yang berbeda, tanpa adanya masalah konflik 
# versi yang dapat terjadi.
# Secara keseluruhan, fitur virtual environment di Python memberikan kemampuan yang sangat berguna untuk 
# mengelola dependensi dan versi library, memastikan reprodusibilitas proyek yang kompleks dan meminimalkan 
# masalah yang mungkin timbul akibat konflik versi. Ini merupakan praktik terbaik dalam pengembangan 
# perangkat lunak yang membantu menjaga konsistensi, portabilitas, dan keberlanjutan proyek secara efektif.

# %%
##

# %%
# Nomor 5
import pandas as pd
import matplotlib.pyplot as plt

# Membaca data
df = pd.read_csv("D:/Users/DELL/Downloads/data13.csv")

# %%
# Grafik tingkat urbanisasi untuk beberapa tahun
plt.figure(figsize=(10, 6))
for year in range(20, 24):
    plt.plot(df['ID'], df[f'UR{year}'], label=f'UR{year}')
plt.title('Tingkat Urbanisasi Berdasarkan Tahun')
plt.xlabel('ID Wilayah')
plt.ylabel('Tingkat Urbanisasi')
plt.legend()
plt.xticks(df['ID'])
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 1. Grafik sebar (scatter plot) dari koordinat (Latitude dan Longitude)
plt.figure(figsize=(10, 6))
plt.scatter(data['LONG'], data['LAT'], c='blue', alpha=0.5)
plt.title('Scatter Plot of Coordinates')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# 2. Grafik batang (bar plot) dari penduduk (POP20) di setiap provinsi
plt.figure(figsize=(12, 6))
plt.bar(data['PROVINCE'], data['POP20'], color='green')
plt.title('Population (POP20) by Province')
plt.xlabel('Province')
plt.ylabel('Population')
plt.xticks(rotation=90)  # Mengatur label sumbu X agar tegak
plt.grid(axis='y')  # Membuat grid hanya pada sumbu Y
plt.tight_layout()  # Memastikan tidak ada label yang tumpang tindih
plt.show()

# %%
# Alasan Penggunaan Grafik Garis untuk Menampilkan Data Tingkat Urbanisasi
# Grafik garis yang Anda tunjukkan merupakan pilihan tepat untuk memvisualisasikan data tingkat 
# urbanisasi karena beberapa alasan berikut:

# 1. Menampilkan Tren Jelas:

# Bentuk garis yang menghubungkan titik data di tahun-tahun berbeda memungkinkan kita untuk melihat tren 
# perubahan tingkat urbanisasi di setiap wilayah secara jelas.
# Kemiringan garis menunjukkan laju perubahan urbanisasi di setiap wilayah.
# Kita dapat dengan mudah mengamati wilayah mana yang mengalami urbanisasi pesat (garis menanjak curam), 
# melambat (garis mendatar/sedikit miring), dan tren umum urbanisasi di berbagai wilayah.

# 2. Membandingkan Antar Wilayah:

# Setiap garis mewakili tingkat urbanisasi di satu wilayah tertentu.
# Dengan membandingkan posisi dan bentuk garis, kita dapat:
# Membandingkan tingkat urbanisasi awal (2020) antar wilayah (posisi garis pada tahun 2020).
# Melihat perbedaan tingkat urbanisasi di tahun 2023 (posisi garis pada tahun 2023).
# Menganalisis kesenjangan urbanisasi antar wilayah (jarak antar garis di setiap tahun).

# 3. Menampilkan Skala dan Kesinambungan Data:

# Grafik garis memungkinkan kita untuk memvisualisasikan skala nilai urbanisasi (0% - 100%) dengan jelas.
# Garis yang menghubungkan titik data menunjukkan perubahan urbanisasi secara berkelanjutan dari tahun ke 
# tahun.
# Bentuk garis secara keseluruhan memberikan gambaran tentang tren jangka panjang urbanisasi di setiap 
# wilayah.

# 4. Kemudahan Interpretasi:

# Grafik garis mudah dibaca dan dipahami oleh khalayak umum.
# Bentuk dan kemiringan garis intuitif untuk menunjukkan tren dan pola dalam data.
# Posisi dan bentuk garis antar wilayah mudah diamati dan dibandingkan.
