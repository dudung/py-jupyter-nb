# %% [markdown]
# ## binary and plot2 -- colors

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

fills = ['b', 'r']
strokes = ['b', 'r']
plot2(x, y, z, strokes=strokes,
      fills=fills)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

fills = ['r', 'b']
strokes = ['b', 'r']
plot2(x, y, z, strokes=strokes,
      fills=fills)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

fills = ['#ccf', '#fcc']
strokes = ['b', 'r']
plot2(x, y, z, strokes=strokes,
      fills=fills)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

fills = ['#ccc', '#cfc']
strokes = ['k', 'g']
plot2(x, y, z, strokes=strokes,
      fills=fills)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

fills = ['#f99', '#fcc']
strokes = ['#f88', '#f88']
plot2(x, y, z, strokes=strokes,
      fills=fills)
