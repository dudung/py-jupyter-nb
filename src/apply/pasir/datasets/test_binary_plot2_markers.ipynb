# %% [markdown]
# ## binary and plot2 -- markers

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

markers = ['o', 's']
plot2(x, y, z, markers=markers)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

markers = ['v', '^']
plot2(x, y, z, markers=markers)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

markers = ['x', 'X']
plot2(x, y, z, markers=markers)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

markers = [1, 2]
plot2(x, y, z, markers=markers)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

markers = ['4', '1']
plot2(x, y, z, markers=markers)
