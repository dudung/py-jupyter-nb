# %%
import keras
from keras import Input, Model
from keras.models import Sequential
from keras.layers import Dense
import visualkeras

inputs = Input(shape=(6,))
hiddens1 = Dense(8, activation='relu')(inputs)
hiddens2 = Dense(4, activation='relu')(hiddens1)
outputs = Dense(2, activation='tanh')(hiddens2)
model = Model(inputs=inputs, outputs=outputs)
visualkeras.graph_view(model,
                       node_size=60,
                       node_spacing=20,
                       layer_spacing=100,
                       padding=10,
                       connector_fill='blue',
                      inout_as_tensor=False)
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# Cell In[42], line 12
#      10 outputs = Dense(2, activation='tanh')(hiddens2)
#      11 model = Model(inputs=inputs, outputs=outputs)
# ---> 12 visualkeras.graph_view(model,
#      13                        node_size=60,
#      14                        node_spacing=20,
#      15                        layer_spacing=100,
#      16                        padding=10,
#      17                        connector_fill='blue',
#      18                       inout_as_tensor=False)
#
# File V:\tf\Lib\site-packages\visualkeras\graph.py:82, in graph_view(model, to_file, color_map, node_size, background_fill, padding, layer_spacing, node_spacing, connector_fill, connector_width, ellipsize_after, inout_as_tensor, show_neurons)
#      76 model_layers = model_to_hierarchy_lists(model, id_to_num_mapping, adj_matrix)
#      78 # Add fake output layers
# ...

# %%
import inspect
print(inspect.signature(visualkeras.graph_view))
# Out:
# (model, to_file: str = None, color_map: dict = None, node_size: int = 50, background_fill: Any = 'white', padding: int = 10, layer_spacing: int = 250, node_spacing: int = 10, connector_fill: Any = 'gray', connector_width: int = 1, ellipsize_after: int = 10, inout_as_tensor: bool = True, show_neurons: bool = True) -> <module 'PIL.Image' from 'V:\\tf\\Lib\\site-packages\\PIL\\Image.py'>

# %%
import keras
from keras import Input, Model
from keras.models import Sequential
from keras.layers import Dense
import visualkeras

inputs = Input(shape=(6,))
hiddens1 = Dense(8, activation='relu')(inputs)
hiddens2 = Dense(4, activation='relu')(hiddens1)
outputs = Dense(2, activation='tanh')(hiddens2)
model = Model(inputs=inputs, outputs=outputs)
visualkeras.layered_view(model)
# Out:
# V:\tf\Lib\site-packages\visualkeras\layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=137x27>

# %%
from keras_visualizer import visualizer

visualizer(model, file_format='png', view=True)

# %%
from keras import models, layers
from keras_visualizer import visualizer

model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(8,)),
    layers.Dense(6, activation='softmax'),
    layers.Dense(32),
    layers.Dense(9, activation='sigmoid')
])

visualizer(model, file_format='png', view=True)
# Out:
# V:\tf\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import visualkeras

visualkeras.graph_view(model)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import visualkeras
# ----> 3 visualkeras.graph_view(model)
#
# File V:\tf\Lib\site-packages\visualkeras\graph.py:58, in graph_view(model, to_file, color_map, node_size, background_fill, padding, layer_spacing, node_spacing, connector_fill, connector_width, ellipsize_after, inout_as_tensor, show_neurons)
#      54 layer_y = list()
#      56 # Attach helper layers
# ---> 58 id_to_num_mapping, adj_matrix = model_to_adj_matrix(model)
#      59 model_layers = model_to_hierarchy_lists(model, id_to_num_mapping, adj_matrix)
#      61 # add fake output layers
#
# File V:\tf\Lib\site-packages\visualkeras\layer_utils.py:54, in model_to_adj_matrix(model)
#      51 if layer_id not in id_to_num_mapping:
#      52     id_to_num_mapping[layer_id] = len(id_to_num_mapping.keys())
# ...

# %%
from tensorflow.keras.utils import plot_model

# Save the model plot to a file
plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True, show_trainable=True)

#inspect.signature(plot_model)

# %%
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# Cell In[21], line 3
#       1 import visualkeras
# ----> 3 visualkeras.graph_view(model)
#
# File V:\tf\Lib\site-packages\visualkeras\graph.py:58, in graph_view(model, to_file, color_map, node_size, background_fill, padding, layer_spacing, node_spacing, connector_fill, connector_width, ellipsize_after, inout_as_tensor, show_neurons)
#      54 layer_y = list()
#      56 # Attach helper layers
# ---> 58 id_to_num_mapping, adj_matrix = model_to_adj_matrix(model)
#      59 model_layers = model_to_hierarchy_lists(model, id_to_num_mapping, adj_matrix)
#      61 # add fake output layers
#
# File V:\tf\Lib\site-packages\visualkeras\layer_utils.py:54, in model_to_adj_matrix(model)
#      51 if layer_id not in id_to_num_mapping:
#      52     id_to_num_mapping[layer_id] = len(id_to_num_mapping.keys())
# ...

# %%
import visualkeras
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim=10, activation='relu'),
    tf.keras.layers.Dense(1)
])
visualkeras.graph_view(model)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# Cell In[25], line 8
#       2 import tensorflow as tf
#       4 model = tf.keras.Sequential([
#       5     tf.keras.layers.Dense(64, input_dim=10, activation='relu'),
#       6     tf.keras.layers.Dense(1)
#       7 ])
# ----> 8 visualkeras.graph_view(model)
#
# File V:\tf\Lib\site-packages\visualkeras\graph.py:58, in graph_view(model, to_file, color_map, node_size, background_fill, padding, layer_spacing, node_spacing, connector_fill, connector_width, ellipsize_after, inout_as_tensor, show_neurons)
#      54 layer_y = list()
#      56 # Attach helper layers
# ---> 58 id_to_num_mapping, adj_matrix = model_to_adj_matrix(model)
#      59 model_layers = model_to_hierarchy_lists(model, id_to_num_mapping, adj_matrix)
#      61 # add fake output layers
#
# File V:\tf\Lib\site-packages\visualkeras\layer_utils.py:54, in model_to_adj_matrix(model)
# ...

# %%
model = Sequential()
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

visualkeras.layered_view(model)

inspect.signature(visualkeras.layered_view)
# Out:
# <Signature (model, to_file: str = None, min_z: int = 20, min_xy: int = 20, max_z: int = 400, max_xy: int = 2000, scale_z: float = 0.1, scale_xy: float = 4, type_ignore: list = None, index_ignore: list = None, color_map: dict = None, one_dim_orientation: str = 'z', index_2D: list = [], background_fill: Any = 'white', draw_volume: bool = True, draw_reversed: bool = False, padding: int = 10, text_callable: Callable[[int, keras.src.layers.layer.Layer], tuple] = None, text_vspacing: int = 4, spacing: int = 10, draw_funnel: bool = True, shade_step=10, legend: bool = False, legend_text_spacing_offset=15, font: <module 'PIL.ImageFont' from 'V:\\tf\\Lib\\site-packages\\PIL\\ImageFont.py'> = None, font_color: Any = 'black', show_dimension=False) -> <module 'PIL.Image' from 'V:\\tf\\Lib\\site-packages\\PIL\\Image.py'>>

# %%
from keras import models, layers
from keras_visualizer import visualizer

model = models.Sequential()
model.add(layers.Conv2D(64, (3, 3), input_shape=(28, 28, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(3))
model.add(layers.Dropout(0.5))
model.add(layers.Activation('sigmoid'))
model.add(layers.Dense(1))

visualizer(model, file_format='png', view=True)
# Out:
# V:\tf\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras import models, layers
from keras_visualizer import visualizer

model = models.Sequential()
model.add(layers.Embedding(64, output_dim=256))
model.add(layers.LSTM(128))
model.add(layers.Dense(1, activation='sigmoid'))

visualizer(model, file_format='png', view=True)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# File V:\tf\Lib\site-packages\keras_visualizer\__init__.py:66, in visualizer(model, file_name, file_format, view, settings)
#      65 try:
# ---> 66     inp_shp = layer.input_shape
#      67 except:
#
# AttributeError: 'Embedding' object has no attribute 'input_shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                           Traceback (most recent call last)
# Cell In[15], line 9
#       6 model.add(layers.LSTM(128))
#       7 model.add(layers.Dense(1, activation='sigmoid'))
# ----> 9 visualizer(model, file_format='png', view=True)
#
# File V:\tf\Lib\site-packages\keras_visualizer\__init__.py:68, in visualizer(model, file_name, file_format, view, settings)
#      66         inp_shp = layer.input_shape
#      67     except:
# ---> 68         inp_shp = layer.input.shape
# ...

# %%
import matplotlib.pyplot as plt
from nnv import NNV

layersList = [
    {"title":"input", "units": 6, "color": "#faa","edges_color":"red", "edges_width":1},
    {"title":"hidden 1\n(relu)", "units": 8,"edges_color":"red", "edges_width":1},
    {"title":"hidden 2\n(relu)", "units": 4,"edges_color":"red", "edges_width":1},
    {"title":"output\n(tanh)", "units": 2,"color": "darkBlue"},
]

NNV(layersList, max_num_nodes_visible=12, spacing_nodes=4, node_radius=10, spacing_layer=60, font_size=12).render()
plt.show()

# %%
import inspect

inspect.signature(NNV)
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# Cell In[28], line 4
#       1 import inspect
#       3 inspect.signature(NNV)
# ----> 4 inspect.signature(plot_model)
#
# NameError: name 'plot_model' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

fig, ax = plt.subplots()

# Circle 1: Only color
circle1 = Circle((0.3, 0.5), 0.2, color='purple')

# Circle 2: Facecolor and edgecolor
circle2 = Circle((0.7, 0.5), 0.2, facecolor='orange', edgecolor='black')

ax.add_patch(circle1)
ax.add_patch(circle2)

plt.xlim(0, 1)
plt.ylim(0, 1)
plt.axis('equal')
plt.show()
