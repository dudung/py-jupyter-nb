# %% [markdown]
# # begprocend
# + url https://mermaid.js.org/config/Tutorials.html

# %%
import base64
from IPython.display import Image, display
import matplotlib.pyplot as plt

def mermaid(graph):
    graphbytes = graph.encode('ascii')
    base64_bytes = base64.b64encode(graphbytes)
    base64_string = base64_bytes.decode('ascii')
    bgcolor = 'bgColor=!gray'
    display(
        Image(
            url='https://mermaid.ink/img/'
            + base64_string + '?' + bgcolor
            )
    )

mermaid("""
graph LR
    A --> B --> C
    A(["Begin"])
    B["Process"]
    C(["End"])
""")
# Out:
# <img src="https://mermaid.ink/img/CmdyYXBoIExSCiAgICBBIC0tPiBCIC0tPiBDCiAgICBBKFsiQmVnaW4iXSkKICAgIEJbIlByb2Nlc3MiXQogICAgQyhbIkVuZCJdKQo=?bgColor=!gray"/>
