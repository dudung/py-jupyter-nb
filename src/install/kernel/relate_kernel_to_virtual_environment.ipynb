# %% [markdown]
# # check_installed_package
# Check installed package installed with pip.

# %% [markdown]
# ## list installed packages
# ![image.png](attachment:image.png)

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ---------
# absl-py                      1.4.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# backcall                     0.2.0
# beautifulsoup4               4.10.0
# bleach                       4.1.0
# butiran                      0.0.9
# cachetools                   5.3.0
# certifi                      2022.12.7
# cffi                         1.15.0
# chardet                      4.0.0
# charset-normalizer           3.0.1
# ChatterBot                   1.0.4
# chatterbot-corpus            1.2.0
# click                        8.1.3
# colorama                     0.4.4
# cycler                       0.11.0
# debugpy                      1.6.0
# decorator                    5.1.1
# defusedxml                   0.7.1
# entrypoints                  0.4
# ...

# %%
# %pip list
# Out:
# Package                      VersionNote: you may need to restart the kernel to use updated packages.
#
# ---------------------------- ---------
# absl-py                      1.4.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# backcall                     0.2.0
# beautifulsoup4               4.10.0
# bleach                       4.1.0
# butiran                      0.0.9
# cachetools                   5.3.0
# certifi                      2022.12.7
# cffi                         1.15.0
# chardet                      4.0.0
# charset-normalizer           3.0.1
# ChatterBot                   1.0.4
# chatterbot-corpus            1.2.0
# click                        8.1.3
# colorama                     0.4.4
# cycler                       0.11.0
# debugpy                      1.6.0
# decorator                    5.1.1
# ...

# %% [markdown]
# ## list installed packages
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Result**:
# ```
# [I 23:32:18.360 NotebookApp] Kernel started: e09cd721-eb5a-49d1-b302-a2111ce645fc, name: avenv
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [I 23:32:21.350 NotebookApp] KernelRestarter: restarting kernel (1/5), new random ports
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [I 23:32:24.449 NotebookApp] KernelRestarter: restarting kernel (2/5), new random ports
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [I 23:32:27.507 NotebookApp] KernelRestarter: restarting kernel (3/5), new random ports
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [I 23:32:30.584 NotebookApp] KernelRestarter: restarting kernel (4/5), new random ports
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [I 23:32:33.648 NotebookApp] KernelRestarter: restarting kernel (5/5), new random ports
# L:\home\py-jupyter-nb\envs\avenv\Scripts\python.exe: No module named ipykernel_launcher
# [W 23:32:36.716 NotebookApp] KernelRestarter: restart failed
# [W 23:32:36.716 NotebookApp] Kernel e09cd721-eb5a-49d1-b302-a2111ce645fc died, removing from map.
# [W 23:33:18.613 NotebookApp] Timeout waiting for kernel_info reply from e09cd721-eb5a-49d1-b302-a2111ce645fc
# ```
# It seems that kernel connect to virtual environment which has not yet `ipykernel_launcher`.
