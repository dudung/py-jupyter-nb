# %% [markdown]
# # mpltern
# + Install and use `mpltern` in a Jupyter notebook.
# + Do not execute this notebook if the library is already installed.

# %% [markdown]
# ## check installation

# %%
# !pip show imageio
# Out:
# WARNING: Package(s) not found: imageio

# %% [markdown]
# ## install
# Jupyter Notebook and other modules are previously installed using pip (at home).

# %%
# !pip install imageio
# Out:
# Collecting imageio
#   Downloading imageio-2.25.0-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 495.2 kB/s eta 0:00:00
# Requirement already satisfied: pillow>=8.3.2 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from imageio) (9.0.1)
# Requirement already satisfied: numpy in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from imageio) (1.22.3)
# Installing collected packages: imageio
# Successfully installed imageio-2.25.0

# %% [markdown]
# **Note**: It can install `imageio` package.

# %% [markdown]
# ## import
# From https://www.geeksforgeeks.org/reading-images-in-python/

# %%
import imageio as iio
img = iio.imread("data/python_180x180.png")
iio.imwrite("data/python_180x180.jpg", img)
# Out:
# C:\Users\Sparisoma Viridi\AppData\Local\Temp\ipykernel_2576\3445222289.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("data/python_180x180.png")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import imageio as iio
#       2 img = iio.imread("data/python_180x180.png")
# ----> 3 iio.imwrite("data/python_180x180.jpg", img)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\v2.py:264, in imwrite(uri, im, format, **kwargs)
#     262 imopen_args["legacy_mode"] = True
#     263 with imopen(uri, "wi", **imopen_args) as file:
# --> 264     return file.write(im, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\legacy_plugin_wrapper.py:253, in LegacyPlugin.write(self, ndimage, is_batch, metadata, **kwargs)
#     246         if not np.issubdtype(image.dtype, np.number) and not np.issubdtype(
#     247             image.dtype, bool
#     248         ):
#     249             raise ValueError(
#     250                 f"All images have to be numeric, and not `{image.dtype}`."
#     251             )
# --> 253         writer.append_data(image, metadata)
#     255 return writer.request.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\format.py:590, in Format.Writer.append_data(self, im, meta)
#     588 im = asarray(im)
#     589 # Call
# --> 590 return self._append_data(im, total_meta)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\plugins\pillow_legacy.py:536, in JPEGFormat.Writer._append_data(self, im, meta)
#     534 def _append_data(self, im, meta):
#     535     if im.ndim == 3 and im.shape[-1] == 4:
# --> 536         raise IOError("JPEG does not support alpha channel.")
#     537     im = image_as_uint(im, bitdepth=8)
#     538     PillowFormat.Writer._append_data(self, im, meta)
#
# OSError: JPEG does not support alpha channel.

# %% [markdown]
# **Error**: Example is outdated. Not yet known what to do. Pause.
#
# **Info**: url https://imageio.readthedocs.io/en/stable/examples.html

# %%
import imageio.v2 as iio
img = iio.imread("data/python_180x180.png")
iio.imwrite("data/python_180x180.jpg", img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 import imageio.v2 as iio
#       2 img = iio.imread("data/python_180x180.png")
# ----> 3 iio.imwrite("data/python_180x180.jpg", img)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\v2.py:264, in imwrite(uri, im, format, **kwargs)
#     262 imopen_args["legacy_mode"] = True
#     263 with imopen(uri, "wi", **imopen_args) as file:
# --> 264     return file.write(im, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\legacy_plugin_wrapper.py:253, in LegacyPlugin.write(self, ndimage, is_batch, metadata, **kwargs)
#     246         if not np.issubdtype(image.dtype, np.number) and not np.issubdtype(
#     247             image.dtype, bool
#     248         ):
#     249             raise ValueError(
#     250                 f"All images have to be numeric, and not `{image.dtype}`."
#     251             )
# --> 253         writer.append_data(image, metadata)
#     255 return writer.request.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\format.py:590, in Format.Writer.append_data(self, im, meta)
#     588 im = asarray(im)
#     589 # Call
# --> 590 return self._append_data(im, total_meta)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\plugins\pillow_legacy.py:536, in JPEGFormat.Writer._append_data(self, im, meta)
#     534 def _append_data(self, im, meta):
#     535     if im.ndim == 3 and im.shape[-1] == 4:
# --> 536         raise IOError("JPEG does not support alpha channel.")
#     537     im = image_as_uint(im, bitdepth=8)
#     538     PillowFormat.Writer._append_data(self, im, meta)
#
# OSError: JPEG does not support alpha channel.

# %%
import imageio.v3 as iio
img = iio.imread("data/python_180x180.png")
iio.imwrite("data/python_180x180.jpg", img)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\JpegImagePlugin.py:630, in _save(im, fp, filename)
#     629 try:
# --> 630     rawmode = RAWMODE[im.mode]
#     631 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 import imageio.v3 as iio
#       2 img = iio.imread("data/python_180x180.png")
# ----> 3 iio.imwrite("data/python_180x180.jpg", img)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\v3.py:147, in imwrite(uri, image, plugin, extension, format_hint, **kwargs)
#     105 """Write an ndimage to the given URI.
#     106
#     107 The exact behavior depends on the file type and plugin used. To learn about
#    (...)
#     136
#     137 """
#     139 with imopen(
#     140     uri,
#     141     "w",
#    (...)
#     145     extension=extension,
#     146 ) as img_file:
# --> 147     encoded = img_file.write(image, **kwargs)
#     149 return encoded
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\plugins\pillow.py:343, in PillowPlugin.write(self, ndimage, mode, format, is_batch, **kwargs)
#     340     save_args["append_images"] = other_images
#     342 save_args.update(kwargs)
# --> 343 primary_image.save(self._request.get_file(), **save_args)
#     345 if self._request._uri_type == URI_BYTES:
#     346     file = cast(BytesIO, self._request.get_file())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\Image.py:2212, in Image.save(self, fp, format, **params)
#    2209         fp = builtins.open(filename, "w+b")
#    2211 try:
# -> 2212     save_handler(self, fp, filename)
#    2213 finally:
#    2214     # do what we can to clean up
#    2215     if open_fp:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\JpegImagePlugin.py:632, in _save(im, fp, filename)
#     630     rawmode = RAWMODE[im.mode]
#     631 except KeyError as e:
# --> 632     raise OSError(f"cannot write mode {im.mode} as JPEG") from e
#     634 info = im.encoderinfo
#     636 dpi = [round(x) for x in info.get("dpi", (0, 0))]
#
# OSError: cannot write mode RGBA as JPEG

# %% [markdown]
# `data/python_180x180.png`<br>
# ![](data/python_180x180.png)
#
#
# `data/python_180x180.jpg`<br>
# ![](data/python_180x180.jpg)
