# %% [markdown]
# # plato_draw
# + Install using shell and use `plato-draw` in a Jupyter notebook.
# + Do not execute related cell in this notebook if the library is not already installed.

# %% [markdown]
# ## check installation

# %%
# !pip show mpl-flow
# Out:
# WARNING: Package(s) not found: mpl-flow

# %% [markdown]
# ## install
# **Note**: Installation is performed in a shell, e.g PowerShell in this example.

# %% [markdown]
# ```
# PS L:\home\py-jupyter-nb> pip install mpl-flow
# Collecting mpl-flow
#   Downloading mpl_flow-1.0.0-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: numpy in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mpl-flow) (1.24.2)
# Requirement already satisfied: matplotlib in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mpl-flow) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (4.31.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mpl-flow) (1.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->mpl-flow) (1.16.0)
# Installing collected packages: mpl-flow
# Successfully installed mpl-flow-1.0.0
# ```

# %% [markdown]
# **Note**: It can install `mpl-flow` package.

# %% [markdown]
# ## import
# Example from [mpl-flow](https://pypi.org/project/mpl-flow/) to test installed package.

# %%
import matplotlib.pyplot as plt
from mpl_flow import Flow

fig, axes = plt.subplots(3, 1, figsize=(8, 12))
ax1, ax2, ax3 = axes
f = Flow(ax=ax1)
f.node(label='first node')
f.node(label='second node')
f.node(label='third node')
f.node(connect=False)

f = Flow(ax=ax2, direction='ns')
f.node(label='first node')
f.node(label='second node')
f.node(label='third node')
f.node(connect=False)

f = Flow(ax=ax3)
f.node(label='first node')
f.node(label='second node', travel='sw')
f.node(label='third node', travel='se')
f.node(connect=False, travel='ne')
# Out:
# (<mpl_flow.Node at 0x1214385d510>, None)
