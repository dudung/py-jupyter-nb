# %% [markdown]
# # data_types_0

# %%
a = 1
print(type(a))
# Out:
# <class 'int'>

# %%
b = -2.5
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Hello, World!"
print(type(c))
# Out:
# <class 'str'>

# %%
d = True
print(type(d))
# Out:
# <class 'bool'>

# %%
e = [a, b, c, d]
print(type(e))
# Out:
# <class 'list'>
