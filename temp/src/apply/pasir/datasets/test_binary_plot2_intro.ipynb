# %% [markdown]
# ## binary and plot2 -- intro

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [-1, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [0, 1], [-1, 0, 0]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0], [0, 1], [0, 0, 0],
          [-1, 0, 0, 0]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[0.41], [-1, -1], [1, 0, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[-0.41], [1, 1], [-1, 0, -1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[1], [-4, -1], [4, 0, 0]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[1], [-1, -4], [0, 0, 4]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[-0.5], [0, 1]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)

# %%
from pasir.datasets.clasdata import binary
from pasir.datasets.dataviz import plot2

r1 = [0, 1.05, 0.05]
r2 = [0, 1.05, 0.05]
coeffs = [[-0.5], [1, 0]]
x, y, z = binary(coeffs, r1=r1, r2=r2)

plot2(x, y, z)
