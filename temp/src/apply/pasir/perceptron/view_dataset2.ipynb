# %% [markdown]
# # view available datasets from dataset2

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [-1, 1, 0],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [-1, 0, 10],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [-1, -1, 20],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [0, -1, 10],  # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [1, -1, 0],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [1, 0, -10],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [1, 1, -20],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [0, 1, -10],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [2, -3, 6],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)

# %%
import matplotlib.pyplot as plt
import ipynb.fs.full.datasets2 as ds2

x, y, z = ds2.linear_separable(
    [0, 20, 1],   # xmin, xmax, dx
    [0, 20, 1],   # ymin, ymax, dy
    [5, 7, -175],   # ax + by + c = 0
)

ds2.plot_dataset(plt, x, y, z)
