# %% [markdown]
# # quadratic_formula
# + url https://ouhammmourachid.github.io/mermaid-py/

# %%
# install memraid-py
# %pip install mermaid-py

# %%
import mermaid as md

# %%
# %%mermaidjs --img
# graph LR
#     B --> I --> P1 --> P2a & P2b --> O --> E
#     B(["Begin"])
#     I["a, b, c"]
#     P1["D = b^2 - 4*a*c"]
#     P2a["x1 = (-b - D^0.5) / (2a)"]
#     P2b["x2 = (-b + D^0.5) / (2a)"]
#     O["x1, x2"]
#     E(["End"])
