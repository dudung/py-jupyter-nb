# %% [markdown]
# # spacy
# + Install using shell and use `spacy` in a Jupyter notebook.
# + Do not execute related cell in this notebook if the library is not already installed.

# %% [markdown]
# ## check installation
# ```
# PS C:\venvs\chatterbot\Scripts> pip show spacy
# WARNING: Package(s) not found: spacy
# ```

# %% [markdown]
# ## activate virtual environment
# ```
# PS C:\venvs\chatterbot\Scripts> c:\venvs\chatterbot\Scripts\activate.ps1
# (chatterbot) PS C:\venvs\chatterbot\Scripts>
# ```

# %% [markdown]
# ## install
# **Note**: Installation is performed in a shell, e.g PowerShell in this example.

# %% [markdown]
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip install spacy
# Collecting spacy
#   Downloading spacy-3.5.0-cp38-cp38-win_amd64.whl (12.6 MB)
#      ---------------------------------------- 12.6/12.6 MB 526.9 kB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging>=20.0 in c:\venvs\chatterbot\lib\site-packages (from spacy) (23.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.5-cp38-cp38-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 766.6 kB/s eta 0:00:00
# Collecting tqdm<5.0.0,>=4.38.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp38-cp38-win_amd64.whl (18 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp38-cp38-win_amd64.whl (481 kB)
#      ---------------------------------------- 481.3/481.3 kB 656.1 kB/s eta 0:00:00
# Collecting numpy>=1.15.0
#   Downloading numpy-1.24.2-cp38-cp38-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 762.0 kB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.13.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Requirement already satisfied: jinja2 in c:\venvs\chatterbot\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\venvs\chatterbot\lib\site-packages (from spacy) (67.1.0)
# Collecting pathy>=0.10.0
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.7/96.7 kB 162.6 kB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp38-cp38-win_amd64.whl (30 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.7-cp38-cp38-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 765.3 kB/s eta 0:00:00
# Collecting typer<0.8.0,>=0.3.0
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp38-cp38-win_amd64.whl (95 kB)
#      ---------------------------------------- 95.8/95.8 kB 390.5 kB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp38-cp38-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 846.0 kB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: colorama in c:\venvs\chatterbot\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click<9.0.0,>=7.1.1
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\venvs\chatterbot\lib\site-packages (from jinja2->spacy) (2.1.2)
# Installing collected packages: cymem, charset-normalizer, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, smart-open, numpy, murmurhash, langcodes, click, certifi, catalogue, typer, srsly, requests, pydantic, preshed, blis, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 certifi-2022.12.7 charset-normalizer-3.0.1 click-8.1.3 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 numpy-1.24.2 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.5 requests-2.28.2 smart-open-6.3.0 spacy-3.5.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.5 thinc-8.1.7 tqdm-4.64.1 typer-0.7.0 typing-extensions-4.5.0 urllib3-1.26.14 wasabi-1.1.1
# ```

# %% [markdown]
# **Note**: It can install `spacy` package.

# %% [markdown]
# ## check packages conflict
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip check
# jupyter-events 0.6.3 has requirement pyyaml>=5.3, but you have pyyaml 3.13.
# ```
#
# **Note**: It might be necessary to downgrade `jupyter-events`, but as long as it works, let it be.

# %% [markdown]
# ## installed packages
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip list
# Package                  Version
# ------------------------ ---------
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# attrs                    22.2.0
# backcall                 0.2.0
# beautifulsoup4           4.11.2
# bleach                   6.0.0
# blis                     0.7.9
# catalogue                2.0.8
# certifi                  2022.12.7
# cffi                     1.15.1
# charset-normalizer       3.0.1
# ChatterBot               1.0.8
# chatterbot-corpus        1.2.0
# click                    8.1.3
# colorama                 0.4.6
# comm                     0.1.2
# confection               0.0.4
# cymem                    2.0.7
# debugpy                  1.6.6
# decorator                5.1.1
# defusedxml               0.7.1
# executing                1.2.0
# fastjsonschema           2.16.3
# fqdn                     1.5.1
# idna                     3.4
# importlib-metadata       6.0.0
# importlib-resources      5.12.0
# ipykernel                6.21.2
# ipython                  8.10.0
# ipython-genutils         0.2.0
# isoduration              20.11.0
# jedi                     0.18.2
# Jinja2                   3.1.2
# jsonpointer              2.3
# jsonschema               4.17.3
# jupyter_client           8.0.3
# jupyter_core             5.2.0
# jupyter-events           0.6.3
# jupyter_server           2.3.0
# jupyter_server_terminals 0.4.4
# jupyterlab-pygments      0.2.2
# langcodes                3.3.0
# MarkupSafe               2.1.2
# mathparse                0.1.2
# matplotlib-inline        0.1.6
# mistune                  2.0.5
# murmurhash               1.0.9
# nbclassic                0.5.2
# nbclient                 0.7.2
# nbconvert                7.2.9
# nbformat                 5.7.3
# nest-asyncio             1.5.6
# notebook                 6.5.2
# notebook_shim            0.2.2
# numpy                    1.24.2
# packaging                23.0
# pandocfilters            1.5.0
# parso                    0.8.3
# pathy                    0.10.1
# pickleshare              0.7.5
# pip                      23.0.1
# pkgutil_resolve_name     1.3.10
# platformdirs             3.0.0
# preshed                  3.0.8
# prometheus-client        0.16.0
# prompt-toolkit           3.0.37
# psutil                   5.9.4
# pure-eval                0.2.2
# pycparser                2.21
# pydantic                 1.10.5
# Pygments                 2.14.0
# pyrsistent               0.19.3
# python-dateutil          2.8.2
# python-json-logger       2.0.7
# pytz                     2022.7.1
# pywin32                  305
# pywinpty                 2.0.10
# PyYAML                   3.13
# pyzmq                    25.0.0
# requests                 2.28.2
# rfc3339-validator        0.1.4
# rfc3986-validator        0.1.1
# Send2Trash               1.8.0
# setuptools               67.1.0
# six                      1.16.0
# smart-open               6.3.0
# sniffio                  1.3.0
# soupsieve                2.4
# spacy                    3.5.0
# spacy-legacy             3.0.12
# spacy-loggers            1.0.4
# SQLAlchemy               1.3.24
# srsly                    2.4.5
# stack-data               0.6.2
# terminado                0.17.1
# thinc                    8.1.7
# tinycss2                 1.2.1
# tornado                  6.2
# tqdm                     4.64.1
# traitlets                5.9.0
# typer                    0.7.0
# typing_extensions        4.5.0
# uri-template             1.2.0
# urllib3                  1.26.14
# wasabi                   1.1.1
# wcwidth                  0.2.6
# webcolors                1.12
# webencodings             0.5.1
# websocket-client         1.5.1
# wheel                    0.38.4
# zipp                     3.15.0
# ```

# %% [markdown]
# ## deactivate virtual environment
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> deactivate
# PS C:\venvs\chatterbot\Scripts>
# ```

# %% [markdown]
# ## uninstall
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip uninstall spacy
# Found existing installation: spacy 3.5.0
# Uninstalling spacy-3.5.0:
#   Would remove:
#     c:\venvs\chatterbot\lib\site-packages\spacy-3.5.0.dist-info\*
#     c:\venvs\chatterbot\lib\site-packages\spacy\*
#     c:\venvs\chatterbot\scripts\spacy.exe
# Proceed (Y/n)? y
#   Successfully uninstalled spacy-3.5.0
# (chatterbot) PS C:\venvs\chatterbot\Scripts>
# ```

# %% [markdown]
# ## install a version
# + Install `13 Jul 2020` `spacy 2.3.2`
# + For `23 Aug 2020` `ChatterBot 1.0.8`
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip install spacy==2.3.2
# Collecting spacy==2.3.2
#   Downloading spacy-2.3.2-cp38-cp38-win_amd64.whl (9.5 MB)
#      ---------------------------------------- 9.5/9.5 MB 874.7 kB/s eta 0:00:00
# Collecting thinc==7.4.1
#   Downloading thinc-7.4.1-cp38-cp38-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 791.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (1.24.2)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp38-cp38-win_amd64.whl (5.0 MB)
#      ---------------------------------------- 5.0/5.0 MB 824.8 kB/s eta 0:00:00
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (2.0.7)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-win_amd64.whl (198 kB)
#      ---------------------------------------- 198.8/198.8 kB 602.4 kB/s eta 0:00:00
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (2.28.2)
# Requirement already satisfied: setuptools in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (67.1.0)
# Collecting wasabi<1.1.0,>=0.4.0
#   Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.3.2) (4.64.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.2) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.2) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.2) (3.4)
# Requirement already satisfied: colorama in c:\venvs\chatterbot\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==2.3.2) (0.4.6)
# Installing collected packages: wasabi, plac, srsly, catalogue, blis, thinc, spacy
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.1
#     Uninstalling wasabi-1.1.1:
#       Successfully uninstalled wasabi-1.1.1
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.5
#     Uninstalling srsly-2.4.5:
#       Successfully uninstalled srsly-2.4.5
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.9
#     Uninstalling blis-0.7.9:
#       Successfully uninstalled blis-0.7.9
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.7
#     Uninstalling thinc-8.1.7:
#       Successfully uninstalled thinc-8.1.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6 which is incompatible.
# Successfully installed blis-0.4.1 catalogue-1.0.2 plac-1.1.3 spacy-2.3.2 srsly-1.0.6 thinc-7.4.1 wasabi-0.10.1
# ```

# %% [markdown]
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip check
# jupyter-events 0.6.3 has requirement pyyaml>=5.3, but you have pyyaml 3.13.
# confection 0.0.4 has requirement srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6.
# ```

# %% [markdown]
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip install srsly==2.4.0
# Collecting srsly==2.4.0
#   Downloading srsly-2.4.0-cp38-cp38-win_amd64.whl (451 kB)
#      ---------------------------------------- 451.5/451.5 kB 543.4 kB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.1
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Installing collected packages: catalogue, srsly
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.2
#     Uninstalling catalogue-1.0.2:
#       Successfully uninstalled catalogue-1.0.2
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.6
#     Uninstalling srsly-1.0.6:
#       Successfully uninstalled srsly-1.0.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 7.4.1 requires catalogue<1.1.0,>=0.0.7, but you have catalogue 2.0.8 which is incompatible.
# thinc 7.4.1 requires srsly<1.1.0,>=0.0.6, but you have srsly 2.4.0 which is incompatible.
# spacy 2.3.2 requires catalogue<1.1.0,>=0.0.7, but you have catalogue 2.0.8 which is incompatible.
# spacy 2.3.2 requires srsly<1.1.0,>=1.0.2, but you have srsly 2.4.0 which is incompatible.
# Successfully installed catalogue-2.0.8 srsly-2.4.0
# ```

# %% [markdown]
# Change to `spacy 2.2.3` 22-nov-2019
# ```
# (chatterbot) PS C:\venvs\chatterbot\Scripts> pip install spacy==2.2.3
# Collecting spacy==2.2.3
#   Downloading spacy-2.2.3-cp38-cp38-win_amd64.whl (9.8 MB)
#      ---------------------------------------- 9.8/9.8 MB 453.7 kB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (2.28.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (1.24.2)
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading thinc-7.3.1-cp38-cp38-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 678.3 kB/s eta 0:00:00
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (1.1.3)
# Collecting srsly<1.1.0,>=0.1.0
#   Using cached srsly-1.0.6-cp38-cp38-win_amd64.whl (198 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (3.0.8)
# Requirement already satisfied: setuptools in c:\venvs\chatterbot\lib\site-packages (from spacy==2.2.3) (67.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\venvs\chatterbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (3.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\venvs\chatterbot\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy==2.2.3) (4.64.1)
# Requirement already satisfied: colorama in c:\venvs\chatterbot\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<7.4.0,>=7.3.0->spacy==2.2.3) (0.4.6)
# Installing collected packages: srsly, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.0
#     Uninstalling srsly-2.4.0:
#       Successfully uninstalled srsly-2.4.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.1
#     Uninstalling thinc-7.4.1:
#       Successfully uninstalled thinc-7.4.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.2
#     Uninstalling spacy-2.3.2:
#       Successfully uninstalled spacy-2.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6 which is incompatible.
# Successfully installed catalogue-1.0.2 spacy-2.2.3 srsly-1.0.6 thinc-7.3.1
# ```
