# %% [markdown]
# # twitter
# + Install and use(?) `twitter` in a Jupyter notebook.
# + There are `python-twitter` ([v3.5 03-nov-2018](https://pypi.org/project/python-twitter/#history)) and `twitter` ([v1.19.6 14-sep-2022](https://pypi.org/project/twitter/#history)).
# + The later is chosen over the former due to most last updated.

# %% [markdown]
# ## check installation
# ```
# PS L:\home\py-jupyter-nb> pip show twitter
# WARNING: Package(s) not found: twitter
# ```

# %% [markdown]
# ## install
# ```
# PS L:\home\py-jupyter-nb> pip install twitter
# Collecting twitter
#   Downloading twitter-1.19.6-py2.py3-none-any.whl (50 kB)
#      -------------------------------------- 50.3/50.3 kB 283.9 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\full name\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from twitter) (2022.12.7)
# Installing collected packages: twitter
# Successfully installed twitter-1.19.6
# ```

# %% [markdown]
# **Note**: It can installed `twitter` package.

# %%
from twitter import *

# url https://developer.twitter.com/en/docs/tutorials/postman-getting-started
token = "1995XXXXX-0NGqVhk3s96IX6SgT3H2bbjOPjcyQXXXXXXX"
token_secret = "rHVuh7dgDuJCOGeoe4tndtjKwWiDjBZHLaZXXXXXX"
consumer_key = "QAktM6W6DF6F7XXXXXX"
consumer_secret = "AJX560A2Omgwyjr6Mml2esedujnZLHXXXXXX"

t = Twitter(auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# Get your "home" timeline
t.statuses.home_timeline()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\twitter\api.py:386, in TwitterCall._handle_response(self, req, uri, arg_data, _timeout)
#     385 kwargs['context'] = context
# --> 386 handle = urllib_request.urlopen(req, **kwargs)
#     387 if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# ...

# %% [markdown]
# **Note**: It can not connect since the token are only as illustration.

# %% [markdown]
# ## get access to twitter api
# 1. [How to get access to the Twitter API](https://developer.twitter.com/en/docs/twitter-api/getting-started/getting-access-to-the-twitter-api)
# 2. [Step 1: Sign up for access](https://developer.twitter.com/en/docs/tutorials/step-by-step-guide-to-making-your-first-request-to-the-twitter-api-v2)
#
# ![image.png](attachment:image.png)
#
# 3. Wait for the email (`04-mar-2023`).

# %% [markdown]
# ## a live request
# + [Try a live request](https://developer.twitter.com/en/docs/twitter-api)
