# %% [markdown]
# # schemdraw
# + Install using shell and use `schemdraw` in a Jupyter notebook.
# + Do not execute related cell in this notebook if the library is not already installed.

# %% [markdown]
# ## check installation

# %%
# !pip show schemdraw
# Out:
# WARNING: Package(s) not found: schemdraw

# %% [markdown]
# ## install
# **Note**: Installation is performed in a shell, e.g PowerShell in this example.

# %% [markdown]
# ```
# PS L:\home\py-jupyter-nb> pip install schemdraw
# Collecting schemdraw
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ------------------------------------ 106.8/106.8 kB 443.0 kB/s eta 0:00:00
# Installing collected packages: schemdraw
# Successfully installed schemdraw-0.15
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\Sparisoma Viridi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#
# PS L:\home\py-jupyter-nb> python -m pip instal --upgrade pip
# ERROR: unknown command "instal" - maybe you meant "install"
# PS L:\home\py-jupyter-nb> python -m pip install --upgrade pip
# Requirement already satisfied: pip in c:\users\sparisoma viridi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (23.0)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 661.1 kB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0
#     Uninstalling pip-23.0:
#       Successfully uninstalled pip-23.0
# Successfully installed pip-23.0.1
# ```

# %% [markdown]
# **Note**: It can install `schemdraw` package.

# %% [markdown]
# ## import
# Example from [schemdraw](https://pypi.org/project/schemdraw/) to test installed package.

# %%
import schemdraw
import schemdraw.elements as elm
with schemdraw.Drawing(file='schematic.svg') as d:
    d += elm.Resistor().label('100KΩ')
    d += elm.Capacitor().down().label('0.1μF', loc='bottom')
    d += elm.Line().left()
    d += elm.Ground()
    d += elm.SourceV().up().label('10V')
