# %%
import matplotlib.pyplot as plt
import math

# %%
N = 200
j = range(0, N)
t = [2 * math.pi * i / N for i in j]
R = 2
x = [R * math.cos(i) for i in t]
y = [R * math.sin(3 * i) for i in t]

# %%
plt.plot(x, y, 'r.')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()
