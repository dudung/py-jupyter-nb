# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [i for i in x]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [-i for i in x]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [i**2 for i in x]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [-i**2 for i in x]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [(i-5)**2 for i in x]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import math

N = 11
x = [i for i in range(N)]
y = [-(i-5)**2 for i in x]

plt.plot(x, y)
plt.show()
