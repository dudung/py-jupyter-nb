# %% [markdown]
# url https://onecompiler.com/python/3yg4egtn7

# %%
nim = 203

per100 = (nim - 1) // 100
gegan = 2 - (nim % 2) 
kelas = per100 * 2 + gegan

print(nim)
print(per100)
print(gegan)
print(kelas)

print(nim, " di kelas ", kelas)
# Out:
# 203
# 2
# 1
# 5
# 203  di kelas  5
