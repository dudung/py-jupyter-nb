# %% [markdown]
# # for_list_break
# A `for` loop can be stopped using `break` before it ends.

# %%
for i in [1, 3, 2, 4, 6, 5]:
    print(i)
# Out:
# 1
# 3
# 2
# 4
# 6
# 5

# %%
for i in [1, 3, 2, 4, 6, 5]:
    print(i)
    if i == 4:
        break
# Out:
# 1
# 3
# 2
# 4
