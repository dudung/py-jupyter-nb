# %% [markdown]
# # html_hello_world
# Examples how to rendered a HTML containing "Hello, World!" message.

# %% [markdown]
# ## a div with css

# %%
from IPython.display import HTML
HTML('''
<div style="
  border:#cc0 1px solid;
  background: #ffc; 
  padding: 10px 20px;
  border-radius: 10px;
  width: 200px;
  text-align: center;
">
Hello, World!
</div>
''')
# Out:
# <div style="
#   border:#cc0 1px solid;
#   background: #ffc;
#   padding: 10px 20px;
#   border-radius: 10px;
#   width: 200px;
#   text-align: center;
# ">
# Hello, World!
# </div>

# %% [markdown]
# ## a button

# %%
from IPython.display import HTML
HTML('''
<button>
Hello, World!
</button>
''')
# Out:
# <button>
# Hello, World!
# </button>

# %% [markdown]
# To see the button please visit [html_hello_world.ipynb](https://nbviewer.org/github/dudung/python-jupyter-notebook/blob/main/html/html_hello_world.ipynb) rendered at [nbviewer](https://nbviewer.org/).
